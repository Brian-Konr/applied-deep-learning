# %%
from tw_rouge import get_rouge
get_rouge('我是人', '我是一個人')
# Out:
# {'rouge-1': {'r': 0.6, 'p': 1.0, 'f': 0.7499999953125},
#  'rouge-2': {'r': 0.25, 'p': 0.5, 'f': 0.33333332888888895},
#  'rouge-l': {'r': 0.6, 'p': 1.0, 'f': 0.7499999953125}}

# %%
# load jsonl file
import pandas as pd
df = pd.read_json('./data/train.jsonl', lines=True)

# %%
df
# Out:
#               date_publish                                  title  \
# 0      2015-03-02 00:00:00  榜首進台大醫科卻休學 、27歲拿到法國天文博士 李悅寧跌破眾人眼鏡返台任教
# 1      2015-10-20 00:00:00           「猩人」真有其事？人猿混種曾成功受孕 揭秘前蘇聯可怕實驗
# 2      2015-12-10 00:00:00                跑步小品／謝謝三浦春馬 再次喚醒我對跑步的熱情
# 3      2016-04-22 00:00:00       【身體不適特輯（下）】「拉肚子」、「想吐」、「嘔吐」英文怎麼說？
# 4      2016-04-29 00:00:00                  中職／球彈、好球帶小 投手被打趴百害無一利
# ...                    ...                                    ...
# 21705  2021-01-13 14:52:07        TDDI IC需求大 手機用年成長8.6％ 平板電腦46.2％
# 21706  2021-01-13 17:31:06                    挪威電信與合勤科技合作進行5G部署計畫
# 21707  2021-01-13 18:00:09             Gowin最新邊緣運算解決方案 採華邦高速記憶體裝置
# 21708  2021-01-13 20:25:06                 CES線上大展 LG發表新筆電搶遠距工作商機
# 21709  2021-01-13 23:04:12            特斯拉公司副總裁陶琳：Model Y本月將開始陸續交付
#
#       source_domain                                           maintext  split  \
# 0           udn.com  從小就很會念書的李悅寧， 在眾人殷殷期盼下，以榜首之姿進入臺大醫學院， 但始終忘不了對天文的...  train
# ...

# %%
valid_df = pd.read_json('./data/public.jsonl', lines=True)
display(valid_df)
# Out:
#              date_publish                                   title  \
# 0     2021-01-14 00:00:00  Anker新款真無線藍牙耳機Liberty Air 2 Pro 引進台灣市場
# 1     2021-01-14 00:00:00           藍染、客家美食、舊山線自行車 「苗栗一日遊」超人氣美食美景
# 2     2021-01-14 00:00:00     華碩打造對應軍規防護與2 in 1設計的15.6吋Chromebook
# 3     2021-01-14 00:00:00                         產業發展變革 台灣的優勢與機會
# 4     2021-01-14 00:00:00     全球Windows 7裝置粗估至少還有1億台以上 市佔率穩穩卡在20％
# ...                   ...                                     ...
# 5489  2021-04-10 00:00:00                  美放寬對台交往規定 一中架構下維持非官方關係
# 5490  2021-04-10 00:00:00                臺虎精釀「福虎祭」開跑！免費入場六大主題玩通海！
# 5491  2021-04-10 00:53:08                      LINE Bank 首月拚20萬開戶
# 5492  2021-04-10 15:00:09           工作做得好 不如馬屁拍得好！10大學校沒教的「職場潛規則」
# 5493  2021-04-10 18:10:09                        掌握四名詞 專家教你看懂長賜輪案
#
#      source_domain                                           maintext split  \
# 0          udn.com  Anker在此次CES 2021中，宣布以旗下Soundcore品牌推出新款真無線藍牙耳機L...   dev
# ...
